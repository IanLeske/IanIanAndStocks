# %% [markdown]
# # Welcome to Jupyter!

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd

# %%
#define the ticker symbol
tickerSymbol = 'aapl'

#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#get the historical prices for this ticker
tickerDf = tickerData.history(period='1d', start='2020-1-1', end='2020-12-28')

#see your data
tickerDf
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2020-01-02   73.425896   74.506568   73.165647   74.444603  135480400
# 2020-01-03   73.651440   74.501596   73.490333   73.720840  146322800
# 2020-01-06   72.818635   74.347924   72.560859   74.308266  118387200
# 2020-01-07   74.318185   74.580916   73.733241   73.958794  108872000
# 2020-01-08   73.653929   75.458346   73.653929   75.148521  132079200
# ...                ...         ...         ...         ...        ...
# 2020-12-18  128.960007  129.100006  126.120003  126.660004  192541500
# 2020-12-21  125.019997  128.309998  123.449997  128.229996  121251600
# 2020-12-22  131.610001  134.410004  129.649994  131.880005  168904800
# 2020-12-23  132.160004  132.429993  130.779999  130.960007   88223700
# 2020-12-24  131.320007  133.460007  131.100006  131.970001   54930100
#
#             Dividends  Stock Splits
# Date
# 2020-01-02        0.0           0.0
# 2020-01-03        0.0           0.0
# 2020-01-06        0.0           0.0
# 2020-01-07        0.0           0.0
# 2020-01-08        0.0           0.0
# ...               ...           ...
# 2020-12-18        0.0           0.0
# 2020-12-21        0.0           0.0
# 2020-12-22        0.0           0.0
# 2020-12-23        0.0           0.0
# 2020-12-24        0.0           0.0
#
# [249 rows x 7 columns]

# %%
tickerDf.plot.line(y='Open')

plt.show()
